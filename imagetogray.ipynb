# %%
import matplotlib.pyplot as plt
import matplotlib.image as matim

# %%
image=matim.imread('image.jpg')

# %%
plt.imshow(image)
plt.show()

# %%
image
# Out:
# array([[[ 37,  99, 158],
#         [ 38, 100, 159],
#         [ 38, 100, 159],
#         ...,
#         [ 38,  92, 152],
#         [ 38,  92, 152],
#         [ 38,  92, 152]],
#
#        [[ 38, 100, 159],
#         [ 38, 100, 159],
#         [ 38, 100, 159],
#         ...,
#         [ 38,  92, 152],
#         [ 38,  92, 152],
#         [ 38,  92, 152]],
#
#        [[ 38, 100, 159],
#         [ 38, 100, 159],
#         [ 38, 100, 159],
#         ...,
#         [ 38,  92, 152],
#         [ 38,  92, 152],
#         [ 38,  92, 152]],
#
#        ...,
#
#        [[ 87, 142, 183],
#         [ 87, 142, 183],
#         [ 87, 142, 183],
#         ...,
#         [ 77, 137, 187],
#         [ 77, 137, 187],
#         [ 77, 137, 187]],
#
#        [[ 88, 141, 185],
#         [ 88, 141, 185],
#         [ 88, 141, 185],
#         ...,
#         [ 80, 136, 185],
#         [ 80, 136, 185],
#         [ 80, 136, 185]],
#
#        [[ 88, 141, 185],
#         [ 88, 141, 185],
#         [ 88, 141, 185],
#         ...,
#         [ 80, 136, 185],
#         [ 80, 136, 185],
#         [ 80, 136, 185]]], dtype=uint8)

# %%
R=image.copy()
print("R channel")
R[:,:,1]=0
R[:,:,2]=0
plt.imshow(R)
# Out:
# R channel

# %%
R.shape
# Out:
# (194, 259, 3)

# %%
G=image.copy()
print("G Channel")
G[:,:,0]=0
G[:,:,2]=0
plt.imshow(G)
# Out:
# G Channel

# %%
B=image.copy()
B[:,:,0]=0
B[:,:,1]=0
plt.imshow(B)

# %%
B
# Out:
# array([[[  0,   0, 158],
#         [  0,   0, 159],
#         [  0,   0, 159],
#         ...,
#         [  0,   0, 152],
#         [  0,   0, 152],
#         [  0,   0, 152]],
#
#        [[  0,   0, 159],
#         [  0,   0, 159],
#         [  0,   0, 159],
#         ...,
#         [  0,   0, 152],
#         [  0,   0, 152],
#         [  0,   0, 152]],
#
#        [[  0,   0, 159],
#         [  0,   0, 159],
#         [  0,   0, 159],
#         ...,
#         [  0,   0, 152],
#         [  0,   0, 152],
#         [  0,   0, 152]],
#
#        ...,
#
#        [[  0,   0, 183],
#         [  0,   0, 183],
#         [  0,   0, 183],
#         ...,
#         [  0,   0, 187],
#         [  0,   0, 187],
#         [  0,   0, 187]],
#
#        [[  0,   0, 185],
#         [  0,   0, 185],
#         [  0,   0, 185],
#         ...,
#         [  0,   0, 185],
#         [  0,   0, 185],
#         [  0,   0, 185]],
#
#        [[  0,   0, 185],
#         [  0,   0, 185],
#         [  0,   0, 185],
#         ...,
#         [  0,   0, 185],
#         [  0,   0, 185],
#         [  0,   0, 185]]], dtype=uint8)

# %%
color=R+G+B
plt.imshow(color)

# %%
grayscale=(((image[:,:,0])//3)+((image[:,:,1])//3)+(image[:,:,2])//3)

# %%
grayscale
# Out:
# array([[ 97,  98,  98, ...,  92,  92,  92],
#        [ 98,  98,  98, ...,  92,  92,  92],
#        [ 98,  98,  98, ...,  92,  92,  92],
#        ...,
#        [137, 137, 137, ..., 132, 132, 132],
#        [137, 137, 137, ..., 132, 132, 132],
#        [137, 137, 137, ..., 132, 132, 132]], dtype=uint8)

# %%
plt.imshow(grayscale,cmap='gray')

# %%
import cv2
cv2.imshow('gm',grayscale)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
gr=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
cv2.imshow('gm',gr)
cv2.waitKey(0)
cv2.destroyAllWindows()
